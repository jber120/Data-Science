# %% [markdown]
# # Applying the CRISP-DM Method to a Business Problem

# %% [markdown]
# CRISP-DM stands for cross-industry process for data mining. It provides a structured approach to planning a data mining project. It is a robust and well-proven methodology.
#
# This model is an idealised sequence of events. In practice many of the tasks can be performed in a different order and it will often be necessary to backtrack to previous tasks and repeat certain actions.

# %% [markdown]
# ![Screenshot-2016-04-20-11.58.54.png](attachment:Screenshot-2016-04-20-11.58.54.png)
#
# **Each phase of the process:**
# 1. [Business understanding](#Businessunderstanding)
#     1. [Assess the Current Situation](#Assessthecurrentsituation)
#         1. [Inventory of resources](#Inventory)
#         2. [Requirements, assumptions and constraints](#Requirements)
#         3. [Risks and contingencies](#Risks)
#         4. [Terminology](#Terminology)
#         5. [Costs and benefits](#CostBenefit)
#     2. [What are the Desired Outputs](#Desiredoutputs)
#     3. [What Questions Are We Trying to Answer?](#QA)
# 2. [Data Understanding](#Dataunderstanding)
#     1. [Initial Data Report](#Datareport)
#     2. [Describe Data](#Describedata)
#     3. [Initial Data Exploration](#Exploredata)
#     4. [Verify Data Quality](#Verifydataquality)
#         1. [Missing Data](#MissingData)
#         2. [Outliers](#Outliers)
#     5. [Data Quality Report](#Dataqualityreport)
# 3. [Data Preparation](#Datapreparation)
#     1. [Select Your Data](#Selectyourdata)
#     2. [Cleanse the Data](#Cleansethedata)
#         1. [Label Encoding](#labelEncoding)
#         2. [Drop Unnecessary Columns](#DropCols)
#         3. [Altering Datatypes](#AlteringDatatypes)
#         4. [Dealing With Zeros](#DealingZeros)
#     3. [Construct Required Data](#Constructrequireddata)
#     4. [Integrate Data](#Integratedata)
# 4. [Exploratory Data Analysis](#EDA)
# 5. [Modelling](#Modelling)
#     1. [Modelling Technique](#ModellingTechnique)
#     2. [Modelling Assumptions](#ModellingAssumptions)
#     3. [Build Model](#BuildModel)
#     4. [Assess Model](#AssessModel)
# 6. [Evaluation](#Evaluation)
# 7. [Deployment](#Deployment)
#
# https://www.sv-europe.com/crisp-dm-methodology/

# %% [markdown]
# # 1. Stage One - Determine Business Objectives and Assess the Situation  <a class="anchor" id="Businessunderstanding"></a>
# The first stage of the CRISP-DM process is to understand what you want to accomplish from a business perspective. Your organisation may have competing objectives and constraints that must be properly balanced. The goal of this stage of the process is to uncover important factors that could influence the outcome of the project. Neglecting this step can mean that a great deal of effort is put into producing the right answers to the wrong questions.

# %% [markdown]
# ## 1.1 Assess the Current Situation<a class="anchor" id="Assessthecurrentsituation"></a>

# %% [markdown]
# This involves more detailed fact-finding about all of the resources, constraints, assumptions and other factors that you'll need to consider when determining your data analysis goal and project plan.

# %% [markdown]
# ### 1.1.1. Inventory of resources <a class="anchor" id="Inventory"></a>
# List the resources available to the project including:
# - Personnel: Jennifer Berryman
# - Data: New York City Bus Data https://www.kaggle.com/datasets/mattop/new-york-city-bus-breakdown-and-delays?resource=download
# - Computing resources: Desktop workstation
# - Software: Jupyter Notebook, Tableau, Microsoft Word

# %% [markdown]
# ### 1.1.2. Requirements, assumptions and constraints - <a class="anchor" id="Requirements"></a>
# - Requirements of the project including the schedule of completion
#     - Business Understanding - July 6th
#     - Data Understanding	- July 8th
#     - Data Preparation - July 10th
#     - Modeling - July 14th
#     - Evaluation - July 20th
#     - Deployment - July 25th
# - Data security concerns as well as any legal issues.
#     - Data is from the public domain with not privacy, security, or legal concerns.
# - Assumptions made by the project. These may be assumptions about the data that can be verified during data mining, but may also include non-verifiable assumptions about the business related to the project. It is particularly important to list the latter if they will affect the validity of the results.
#     - One assumption is that similar school systems may experience similar issues with their transportation departments, which would impact the prediction capabilities. There's also the potential that things like traffic/times of day, and physical geography play a larger role in the likelihood of a breakdown/delay for a school bus, which is not applicable to areas with different patterns of traffic, school start times, or phsyical geography.
# - List the constraints on the project.
#      - The project is a multi-year dataset generated by New York City school buses. This is limited in that it is one school system, and the data was not collected specifically for the purpose of this analysis. There are other factors that may be influencial that were not included in the data collection process because it was not relevant to the process of logging the breakdowns/delays. This could mean that there are additional factors that are not identified within this study.

# %% [markdown]
# ### 1.1.3.Risks and contingencies <a class="anchor" id="Risks"></a>
# - List the risks or events that might delay the project or cause it to fail.
#     - Time Allocation - The amount of time that each component of the project takes is the most likely reason for a delay.
#     - Scope - Going outside of the scope of this project may add addtional time/requirements.
# - what action will you take if these risks or events take place?
#     - Time has been planned for the project by day for a spefici task and number of hours. I've added some time for flexibility in case specific tasks are taking longer than anticipated.
#     - The scope has been define, and with each step I will consider it's relationship with the scope of the project to determine how to properly move forward without going beyond the scope.

# %% [markdown]
#  ## 1.2 What are the desired outputs of the project? <a class="anchor" id="Desiredoutputs"></a>

# %% [markdown]
# - Criterion 1: Which factors are most often associated with bus breakdowns/delays.
#     - Required Component: Descriptive statistical analysis on the cleaned dataset will determine these factors.
#     - Success Criteria: Success if clear relationships between factors and bus breakdowns/delays can be identified.
# - Criterion 2:Create a model that can accurately predict the likelihood of a breakdown/delay.
#     - Required Component: A subset of the data to create a model, then comparing the dataset to the model created will determine the success at creating a good model.
#     - Success Criteria: The model predicts school bus breakdowns/delays with at least 85% accuracy when applied to the whole dataset, which would present realistic performance and not indicate overfitting.
# - Criterion 3:Communicate the findings of the previous objectives into a report.
#     - Required Component: A final report containing the findings, breakdown of data, and visualizations will be created to communicate findings.
#     - Success Criteria: The report meets all criteria set forth in the rubric for task three with a score of competent.

# %% [markdown]
#  ## 1.3 What Questions Are We Trying To Answer? <a class="anchor" id="QA"></a>

# %% [markdown]
# - Question: How can the New York City school bus operations be improved to support potential breakdowns and delays based on known factors from the 2015-2022 school years?
# - Hypothesis: If there is a breakdown or delay it is most likely going to be due to physical components on the school bus, such as tires, brakes, or other similar items. While other factors, such as routes, or time of day, may be related to experiencing a breakdown or delay, the physical components themselves will have a stronger relationship.

# %% [markdown]
# # 2. Stage  Two - Data Understanding <a class="anchor" id="Dataunderstanding"></a>
# The second stage of the CRISP-DM process requires you to acquire the data listed in the project resources. This initial collection includes data loading, if this is necessary for data understanding. For example, if you use a specific tool for data understanding, it makes perfect sense to load your data into this tool. If you acquire multiple data sources then you need to consider how and when you're going to integrate these.

# %% [markdown]
# ## 2.1 Initial Data Report <a class="anchor" id="Datareport"></a>
# Initial data collection report -
# List the data sources acquired together with their locations, the methods used to acquire them and any problems encountered. Record problems you encountered and any resolutions achieved. This will help both with future replication of this project and with the execution of similar future projects.

# %%
# import libraries here; add more as necessary
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import StandardScaler
from scipy.sparse import csr_matrix

# %matplotlib inline

# %%
bus_data_df = pd.read_csv('bus-breakdowns-delays.csv', low_memory=False)
bus_data_df.head(3)
# Out:
#   School_Year  Busbreakdown_ID           Run_Type Bus_No Route_Number  \
# 0   2015-2016          1227538  Special Ed AM Run   2621         J711
# 1   2015-2016          1227539  Special Ed AM Run   1260         M351
# 2   2015-2016          1227540           Pre-K/EI    418            3
#
#           Reason Schools_Serviced             Occurred_On  \
# 0  Heavy Traffic            75003  11/05/2015 08:10:00 AM
# 1  Heavy Traffic            06716  11/05/2015 08:10:00 AM
# 2  Heavy Traffic             C445  11/05/2015 08:09:00 AM
#
#                Created_On        Boro  ... How_Long_Delayed  \
# 0  11/05/2015 08:12:00 AM  New Jersey  ...              NaN
# 1  11/05/2015 08:12:00 AM   Manhattan  ...            20MNS
# 2  11/05/2015 08:13:00 AM       Bronx  ...            15MIN
#
#   Number_Of_Students_On_The_Bus  Has_Contractor_Notified_Schools  \
# 0                            11                              Yes
# 1                             2                              Yes
# ...

# %% [markdown]
# ## 2.2 Describe Data <a class="anchor" id="Describedata"></a>
# Data description report - Describe the data that has been acquired including its format, its quantity (for example, the number of records and fields in each table), the identities of the fields and any other surface features which have been discovered. Evaluate whether the data acquired satisfies your requirements.

# %%
bus_data_df.columns
# Out:
# Index(['School_Year', 'Busbreakdown_ID', 'Run_Type', 'Bus_No', 'Route_Number',
#        'Reason', 'Schools_Serviced', 'Occurred_On', 'Created_On', 'Boro',
#        'Bus_Company_Name', 'How_Long_Delayed', 'Number_Of_Students_On_The_Bus',
#        'Has_Contractor_Notified_Schools', 'Has_Contractor_Notified_Parents',
#        'Have_You_Alerted_OPT', 'Informed_On', 'Incident_Number',
#        'Last_Updated_On', 'Breakdown_or_Running_Late', 'School_Age_or_PreK'],
#       dtype='object')

# %%
bus_data_df.shape
# Out:
# (545691, 21)

# %%
bus_data_df.dtypes
# Out:
# School_Year                        object
# Busbreakdown_ID                     int64
# Run_Type                           object
# Bus_No                             object
# Route_Number                       object
# Reason                             object
# Schools_Serviced                   object
# Occurred_On                        object
# Created_On                         object
# Boro                               object
# Bus_Company_Name                   object
# How_Long_Delayed                   object
# Number_Of_Students_On_The_Bus       int64
# Has_Contractor_Notified_Schools    object
# Has_Contractor_Notified_Parents    object
# Have_You_Alerted_OPT               object
# Informed_On                        object
# Incident_Number                    object
# Last_Updated_On                    object
# Breakdown_or_Running_Late          object
# School_Age_or_PreK                 object
# dtype: object

# %%
bus_data_df.describe()
# Out:
#        Busbreakdown_ID  Number_Of_Students_On_The_Bus
# count     5.456910e+05                  545691.000000
# mean      1.494128e+06                       3.194526
# std       1.644849e+05                      70.974113
# min       1.212681e+06                       0.000000
# 25%       1.350956e+06                       0.000000
# 50%       1.493348e+06                       0.000000
# 75%       1.635440e+06                       3.000000
# max       1.781947e+06                    9658.000000

# %%
bus_data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 545691 entries, 0 to 545690
# Data columns (total 21 columns):
#  #   Column                           Non-Null Count   Dtype
# ---  ------                           --------------   -----
#  0   School_Year                      545691 non-null  object
#  1   Busbreakdown_ID                  545691 non-null  int64
#  2   Run_Type                         545685 non-null  object
#  3   Bus_No                           545678 non-null  object
#  4   Route_Number                     545684 non-null  object
#  5   Reason                           545689 non-null  object
#  6   Schools_Serviced                 545684 non-null  object
#  7   Occurred_On                      545691 non-null  object
#  8   Created_On                       545691 non-null  object
#  9   Boro                             534474 non-null  object
#  10  Bus_Company_Name                 545691 non-null  object
# ...

# %%
bus_data_df['How_Long_Delayed'].value_counts()
# Out:
# 31-45 Min    119486
# 16-30 Min    111475
# 46-60 Min     64958
# 0-15 Min      40152
# 61-90 Min     27713
#               ...
# 10mnt             1
# 220MIN            1
# 25  mins          1
# -10MINS           1
# 1133              1
# Name: How_Long_Delayed, Length: 1877, dtype: int64

# %% [markdown]
# ## 2.3 Verify Data Quality <a class="anchor" id="Verifydataquality"></a>
#
# Examine the quality of the data, addressing questions such as:
#
# - Is it correct, or does it contain errors and, if there are errors, how common are they?
#     - While not errors necessarily, there is inconsistency in the values entered in some of the columns. For instance, the first three rows show that the abbeviation for the word "minutes" is not consistent. I will account for this inconsistency by removing the string from the number of minutes, and identifying if any hours are present that need to be converted.
# - Is the data complete?
#     - There examples of missing values, or NaNs, in the data set. These will need to be addressed when conducting data cleaning. The incident number, for example, is missing over 500,000 values. This column can be deleted, as the breakdown_id will be used as the unique identifier. The Boro column, incidating which "borough" the bus route is in, is missing a lot of data, which is unfortunate because that would have provided good geogrphic information for each bus route.

# %% [markdown]
# ### 2.3.1. Missing Data <a class="anchor" id="MissingData"></a>
# In addition to incorrect datatypes, another common problem when dealing with real-world data is missing values. These can arise for many reasons and have to be either filled in or removed before we train a machine learning model. First, let’s get a sense of how many missing values are in each column
#
# While we always want to be careful about removing information, if a column has a high percentage of missing values, then it probably will not be useful to our model. The threshold for removing columns should depend on the problem

# %%
bus_data_df.isnull().sum()
# Out:
# School_Year                             0
# Busbreakdown_ID                         0
# Run_Type                                6
# Bus_No                                 13
# Route_Number                            7
# Reason                                  2
# Schools_Serviced                        7
# Occurred_On                             0
# Created_On                              0
# Boro                                11217
# Bus_Company_Name                        0
# How_Long_Delayed                    54064
# Number_Of_Students_On_The_Bus           0
# Has_Contractor_Notified_Schools         0
# Has_Contractor_Notified_Parents         0
# Have_You_Alerted_OPT                    0
# Informed_On                             0
# Incident_Number                    534801
# Last_Updated_On                         0
# Breakdown_or_Running_Late               0
# School_Age_or_PreK                      0
# dtype: int64

# %%
def missing_values_table(df):
        mis_val = df.isnull().sum()
        mis_val_percent = 100 * df.isnull().sum() / len(df)
        mis_val_table = pd.concat([mis_val, mis_val_percent], axis=1)
        mis_val_table_ren_columns = mis_val_table.rename(
        columns = {0 : 'Missing Values', 1 : '% of Total Values'})
        mis_val_table_ren_columns = mis_val_table_ren_columns[
            mis_val_table_ren_columns.iloc[:,1] != 0].sort_values(
        '% of Total Values', ascending=False).round(1)
        print ("Your selected dataframe has " + str(df.shape[1]) + " columns.\n"      
            "There are " + str(mis_val_table_ren_columns.shape[0]) +
              " columns that have missing values.")
        return mis_val_table_ren_columns

# %%
missing_values_table(bus_data_df)
# Out:
# Your selected dataframe has 21 columns.
# There are 8 columns that have missing values.
#                   Missing Values  % of Total Values
# Incident_Number           534801               98.0
# How_Long_Delayed           54064                9.9
# Boro                       11217                2.1
# Bus_No                        13                0.0
# Route_Number                   7                0.0
# Schools_Serviced               7                0.0
# Run_Type                       6                0.0
# Reason                         2                0.0

# %%
# Get the columns with > 50% missing
missing_df = missing_values_table(bus_data_df);
missing_columns = list(missing_df[missing_df['% of Total Values'] > 50].index)
print('We will remove %d columns.' % len(missing_columns))
# Out:
# Your selected dataframe has 21 columns.
# There are 8 columns that have missing values.
# We will remove 1 columns.

# %%
# Drop the columns
bus_data_clean_df = bus_data_df.drop(list(missing_columns), axis=1)
bus_data_clean_df.columns
# Out:
# Index(['School_Year', 'Busbreakdown_ID', 'Run_Type', 'Bus_No', 'Route_Number',
#        'Reason', 'Schools_Serviced', 'Occurred_On', 'Created_On', 'Boro',
#        'Bus_Company_Name', 'How_Long_Delayed', 'Number_Of_Students_On_The_Bus',
#        'Has_Contractor_Notified_Schools', 'Has_Contractor_Notified_Parents',
#        'Have_You_Alerted_OPT', 'Informed_On', 'Last_Updated_On',
#        'Breakdown_or_Running_Late', 'School_Age_or_PreK'],
#       dtype='object')

# %% [markdown]
# ### 2.3.2. Outliers <a class="anchor" id="Outliers"></a>
# At this point, we may also want to remove outliers. These can be due to typos in data entry, mistakes in units, or they could be legitimate but extreme values. For this project, we will remove anomalies based on the definition of extreme outliers:
#
# https://www.itl.nist.gov/div898/handbook/prc/section1/prc16.htm
#
# - Below the first quartile − 3 ∗ interquartile range
# - Above the third quartile + 3 ∗ interquartile range

# %%
def remove_outliers(df): 
    q1 = df.quantile(0.25)
    q3 = df.quantile(0.75)
    IQR = q3-q1
    df_IQR = df[~((df<(q1-1.5*IQR)) | (df>(q3+1.5*IQR)))]
    return df_IQR

# %%
df_IQR = remove_outliers(bus_data_clean_df)

df_IQR.head(3)
# Out:
#   School_Year  Busbreakdown_ID           Run_Type Bus_No Route_Number  \
# 0   2015-2016          1227538  Special Ed AM Run   2621         J711
# 1   2015-2016          1227539  Special Ed AM Run   1260         M351
# 2   2015-2016          1227540           Pre-K/EI    418            3
#
#           Reason Schools_Serviced             Occurred_On  \
# 0  Heavy Traffic            75003  11/05/2015 08:10:00 AM
# 1  Heavy Traffic            06716  11/05/2015 08:10:00 AM
# 2  Heavy Traffic             C445  11/05/2015 08:09:00 AM
#
#                Created_On        Boro           Bus_Company_Name  \
# 0  11/05/2015 08:12:00 AM  New Jersey  RELIANT TRANS, INC. (B232
# 1  11/05/2015 08:12:00 AM   Manhattan  HOYT TRANSPORTATION CORP.
# 2  11/05/2015 08:13:00 AM       Bronx               G.V.C., LTD.
#
#   How_Long_Delayed  Number_Of_Students_On_The_Bus  \
# 0              NaN                            NaN
# 1            20MNS                            2.0
# ...

# %%
df_IQR['Bus_No'].value_counts()
# Out:
# 1801          1037
# 1470           867
# 1318           860
# 1107           796
# 1803           791
#               ...
# NI06376          1
# 016148BELT       1
# GV09304          1
# 20277            1
# 29494            1
# Name: Bus_No, Length: 17545, dtype: int64

# %%
df_IQR['Number_Of_Students_On_The_Bus'].value_counts()
# Out:
# 0.0    334167
# 1.0     34151
# 2.0     32646
# 3.0     29295
# 4.0     24928
# 5.0     23108
# 6.0     14290
# 7.0     12144
# Name: Number_Of_Students_On_The_Bus, dtype: int64

# %%
bus_data_clean_df['Number_Of_Students_On_The_Bus'].value_counts()
# Out:
# 0       334167
# 1        34151
# 2        32646
# 3        29295
# 4        24928
#          ...
# 1324         1
# 2351         1
# 4402         1
# 1330         1
# 198          1
# Name: Number_Of_Students_On_The_Bus, Length: 335, dtype: int64

# %% [markdown]
# The value counts for "Number of Students On the Bus" had several outliers removed, as having 1324, or even 198 students on a bus seems improbable. This verifies that outliers were removed using the function that was created.

# %% [markdown]
# ## 2.4 Initial Data Exploration  <a class="anchor" id="Exploredata"></a>
# During this stage you'll address data mining questions using querying, data visualization and reporting techniques.

# %% [markdown]
# ### 2.4.1 Distributions  <a class="anchor" id="Distributions"></a>

# %%
def count_values_table(df):
        count_val = df.value_counts()
        count_val_percent = 100 * df.value_counts() / len(df)
        count_val_table = pd.concat([count_val, count_val_percent.round(1)], axis=1)
        count_val_table_ren_columns = count_val_table.rename(
        columns = {0 : 'Count Values', 1 : '% of Total Values'})
        return count_val_table_ren_columns

# %%
# Histogram
def hist_chart(df, col):
        plt.figure(figsize=(10, 15))
        plt.style.use('fivethirtyeight')
        plt.hist(df[col].dropna(), edgecolor = 'k');
        plt.xlabel(col); plt.ylabel('Number of Entries',rotation='vertical'); 
        plt.title('Distribution of '+col);

# %%
col = 'How_Long_Delayed'
# Histogram & Results
hist_chart(df_IQR, col)
count_values_table(df_IQR[col])
# Out:
#            How_Long_Delayed  How_Long_Delayed
# 31-45 Min            119486              21.9
# 16-30 Min            111475              20.4
# 46-60 Min             64958              11.9
# 0-15 Min              40152               7.4
# 61-90 Min             27713               5.1
# ...                     ...               ...
# 10mnt                     1               0.0
# 220MIN                    1               0.0
# 25  mins                  1               0.0
# -10MINS                   1               0.0
# 1133                      1               0.0
#
# [1877 rows x 2 columns]

# %% [markdown]
# Most delays don't take that long, with over 71.6% of the data falling within 0-15, 16-30, 31-45, and 46-60 minutes logged. Based on the observation that not all data is logged consistently, cleaning this column to break down into categories of time in separate columns would be more helpful in analyzing the length of breakdowns. This should be done in the data cleaning process.

# %%
col = 'Reason'
# Histogram & Results
hist_chart(df_IQR, col)
count_values_table(df_IQR[col])
# Out:
#                              Reason  Reason
# Heavy Traffic                341972    62.7
# Other                         79954    14.7
# Mechanical Problem            51807     9.5
# Won`t Start                   18111     3.3
# Flat Tire                     13577     2.5
# Problem Run                   12823     2.3
# Weather Conditions            10417     1.9
# Late return from Field Trip    8231     1.5
# Accident                       4896     0.9
# Delayed by School              3901     0.7

# %%
df_IQR['Breakdown_or_Running_Late'].value_counts()
# Out:
# Running Late    496178
# Breakdown        49513
# Name: Breakdown_or_Running_Late, dtype: int64

# %% [markdown]
# Heavy Traffic was the cause for 63% of delays. This may indicate that the dataset would benefit from being broken down into "Breakdowns" and "Delays" to differentiate between the two. The column "Breakdown Or Running Late" would help identify between the two so that the "Other" value that is in the Reason column can be accounted for. 90% of buses were categorized as delayed rather than breakdowns.

# %% [markdown]
# ### 2.4.2 Correlations  <a class="anchor" id="Correlations"></a>
# Can we derive any correlation from this data-set. Pairplot chart gives us correlations, distributions and regression path
# Correlogram are awesome for exploratory analysis. It allows to quickly observe the relationship between every variable of your matrix.
# It is easy to do it with seaborn: just call the pairplot function
#
# Pairplot Documentation cab be found here: https://seaborn.pydata.org/generated/seaborn.pairplot.html

# %%
def Correlation_Plotting(df, cat_col):
    sns.pairplot(df, hue=cat_col, kind='reg')
    plt.show()

# %% [markdown]
# After running this function on with "Breakdown or Running Late" as the categorical value, it was decided that starting with cleaning would be most help so that I can have appropriate values assessed. Currently only the breakdown_ID and number of students on the bus would show when analyzing the correlation.

# %% [markdown]
# ## 2.5 Data Quality Report <a class="anchor" id="Dataqualityreport"></a>
# List the results of the data quality verification. If quality problems exist, suggest possible solutions. Solutions to data quality problems generally depend heavily on both data and business knowledge.

# %% [markdown]
# Some data quality concerns have been addressed, but more can be done. Cleaning the data, then re-running the descriptive analysis will provide better insight into the dataset.

# %% [markdown]
# # 3. Stage Three - Data Preperation <a class="anchor" id="Datapreperation"></a>
# This is the stage of the project where you decide on the data that you're going to use for analysis. The criteria you might use to make this decision include the relevance of the data to your data mining goals, the quality of the data, and also technical constraints such as limits on data volume or data types. Note that data selection covers selection of attributes (columns) as well as selection of records (rows) in a table.

# %% [markdown]
# ## 3.1 Select Your Data <a class="anchor" id="Selectyourdata"></a>
# This is the stage of the project where you decide on the data that you're going to use for analysis. The criteria you might use to make this decision include the relevance of the data to your data mining goals, the quality of the data, and also technical constraints such as limits on data volume or data types. Note that data selection covers selection of attributes (columns) as well as selection of records (rows) in a table.

# %% [markdown]
# ## 3.2 Construct Required Data   <a class="anchor" id="Constructrequireddata"></a>
# This task includes constructive data preparation operations such as the production of derived attributes or entire new records, or transformed values for existing attributes.
#
# **Derived attributes** - These are new attributes that are constructed from one or more existing attributes in the same record, for example you might use the variables of length and width to calculate a new variable of area.
# - Buckets for length of time of the breakdown/delay using the How long Delayed column.

# %%
import re

df_IQR['How_Long_Delayed'] = df_IQR['How_Long_Delayed'].astype(str)

def multiply_hour_to_minutes(string):
    pattern = r'(\d+)\s*(?:hour|hours)'
    match = re.search(pattern, string)
    if match:
        hours = int(match.group(1))
        minutes = hours * 60
        return minutes

def set_delay_range(string):
    pattern = r'\d+'  # Regular expression pattern to match integers
    matches = re.findall(pattern, string)
    integers = [int(match) for match in matches]
    if integers:
        minimum = min(integers)
        if minimum >= 0 and minimum <= 15:
            return '0-15'
        elif minimum >= 16 and minimum <= 30:
            return '16-30'
        elif minimum >= 31 and minimum <= 45:
            return '31-45'
        elif minimum >= 46 and minimum <= 60:
            return '46-60'
        elif minimum >= 61 and minimum <= 90:
            return '61-90'
        else:
            return '90+'
    else:
        return None

df_IQR['Minutes Delayed'] = df_IQR['How_Long_Delayed'].astype(str).apply(set_delay_range)

# %%
df_IQR.head(5)
# Out:
#   School_Year  Busbreakdown_ID           Run_Type Bus_No Route_Number  \
# 0   2015-2016          1227538  Special Ed AM Run   2621         J711
# 1   2015-2016          1227539  Special Ed AM Run   1260         M351
# 2   2015-2016          1227540           Pre-K/EI    418            3
# 3   2015-2016          1227541  Special Ed AM Run   4522         M271
# 4   2015-2016          1227542  Special Ed AM Run   3124         M373
#
#           Reason Schools_Serviced             Occurred_On  \
# 0  Heavy Traffic            75003  11/05/2015 08:10:00 AM
# 1  Heavy Traffic            06716  11/05/2015 08:10:00 AM
# 2  Heavy Traffic             C445  11/05/2015 08:09:00 AM
# 3  Heavy Traffic            02699  11/05/2015 08:12:00 AM
# 4  Heavy Traffic            02116  11/05/2015 08:13:00 AM
#
#                Created_On        Boro  ... How_Long_Delayed  \
# 0  11/05/2015 08:12:00 AM  New Jersey  ...              nan
# 1  11/05/2015 08:12:00 AM   Manhattan  ...            20MNS
# ...

# %%
df_IQR['Minutes Delayed'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0          None
# 1         16-30
# 2          0-15
# 3          0-15
# 4          None
#           ...
# 545686    61-90
# 545687    61-90
# 545688    61-90
# 545689    61-90
# 545690    46-60
# Name: Minutes Delayed, Length: 545691, dtype: object>

# %%
col = 'Minutes Delayed'
# Histogram & Results
hist_chart(df_IQR, col)
count_values_table(df_IQR[col])
# Out:
#        Minutes Delayed  Minutes Delayed
# 16-30           180901             33.2
# 31-45           135666             24.9
# 0-15             78905             14.5
# 46-60            67232             12.3
# 61-90            28060              5.1
# 90+                363              0.1

# %% [markdown]
# ## 3.3Clean The Data <a class="anchor" id="Cleansethedata"></a>
# This task involves raise the data quality to the level required by the analysis techniques that you've selected. This may involve selecting clean subsets of the data, the insertion of suitable defaults, or more ambitious techniques such as the estimation of missing data by modelling.

# %% [markdown]
# ### 3.3.1 Label Encoding <a class="anchor" id="labelEncoding"></a>
# Label Encoding to turn Categorical values to Integers
#
# An approach to encoding categorical values is to use a technique called label encoding. Label encoding is simply converting each value in a column to a number. For example, the body_style column contains 5 different values. We could choose to encode it like this:
#
# convertible -> 0
# hardtop -> 1
# hatchback -> 2
# sedan -> 3
# wagon -> 4
# http://pbpython.com/categorical-encoding.html

# %%
obj_cat_cols = df_IQR.select_dtypes(include=['object']).columns

# %%
from sklearn.preprocessing import OneHotEncoder, LabelEncoder
df_IQR_decoded = df_IQR.copy()
for col in obj_cat_cols:
        encoder = LabelEncoder()
        df_IQR[col] = encoder.fit_transform(df_IQR[col].astype(str))

# %%
df_IQR_decoded.head(2)
# Out:
#   School_Year  Busbreakdown_ID           Run_Type Bus_No Route_Number  \
# 0   2015-2016          1227538  Special Ed AM Run   2621         J711
# 1   2015-2016          1227539  Special Ed AM Run   1260         M351
#
#           Reason Schools_Serviced             Occurred_On  \
# 0  Heavy Traffic            75003  11/05/2015 08:10:00 AM
# 1  Heavy Traffic            06716  11/05/2015 08:10:00 AM
#
#                Created_On        Boro  ... How_Long_Delayed  \
# 0  11/05/2015 08:12:00 AM  New Jersey  ...              nan
# 1  11/05/2015 08:12:00 AM   Manhattan  ...            20MNS
#
#   Number_Of_Students_On_The_Bus  Has_Contractor_Notified_Schools  \
# 0                           NaN                              Yes
# 1                           2.0                              Yes
#
#   Has_Contractor_Notified_Parents Have_You_Alerted_OPT  \
# 0                              No                  Yes
# 1                             Yes                   No
#
# ...

# %%
for col in obj_cat_cols:
        df_IQR[col] = df_IQR[col].astype('category')
df_IQR.dtypes
# Out:
# School_Year                        category
# Busbreakdown_ID                       int64
# Run_Type                           category
# Bus_No                             category
# Route_Number                       category
# Reason                             category
# Schools_Serviced                   category
# Occurred_On                        category
# Created_On                         category
# Boro                               category
# Bus_Company_Name                   category
# How_Long_Delayed                   category
# Number_Of_Students_On_The_Bus       float64
# Has_Contractor_Notified_Schools    category
# Has_Contractor_Notified_Parents    category
# Have_You_Alerted_OPT               category
# Informed_On                        category
# Last_Updated_On                    category
# Breakdown_or_Running_Late          category
# School_Age_or_PreK                 category
# Minutes Delayed                    category
# dtype: object

# %%
for col in obj_cat_cols:
    df_IQR[col] = df_IQR[col].cat.codes
df_IQR.head()
# Out:
#    School_Year  Busbreakdown_ID  Run_Type  Bus_No  Route_Number  Reason  \
# 0            0          1227538         7    5689          2570       3
# 1            0          1227539         7    1769          6842       3
# 2            0          1227540         3    7678           470       3
# 3            0          1227541         7    8212          6753       3
# 4            0          1227542         7    6723          6865       3
#
#    Schools_Serviced  Occurred_On  Created_On  Boro  ...  How_Long_Delayed  \
# 0             30157       195577      211460     6  ...              1873
# 1              5823       195577      211460     4  ...               764
# 2             30427       195576      211461     1  ...               454
# 3              2553       195578      211462     4  ...               330
# 4              1507       195579      211462     4  ...              1873
#
#    Number_Of_Students_On_The_Bus  Has_Contractor_Notified_Schools  \
# ...

# %% [markdown]
# ### 3.3.2 Dropping Columns  <a class="anchor" id="AlteringDatatypes"></a>
# Columns that are not relevent to the research question can be dropped. In this case, I've dropped the columns regarding the transportation departments communication to stakeholders, as that is not a relevant feature to my analysis.

# %%
cols = ['Has_Contractor_Notified_Schools', 'Has_Contractor_Notified_Parents','Have_You_Alerted_OPT','Informed_On','Last_Updated_On', 'How_Long_Delayed', 'Schools_Serviced', 'Created_On','School_Age_or_PreK']
df_IQR_dropped = df_IQR.drop(cols, axis=1)
df_IQR_decoded = df_IQR_decoded.drop(cols, axis=1)

# %% [markdown]
# ### 3.3.3 Dropping NaNs

# %%
for col in df_IQR_decoded:
    df_IQR_decoded[col] = df_IQR_decoded[col].replace(['', 'NA', 'nan'], np.nan)
    df_IQR_decoded = df_IQR_decoded.dropna()

# %% [markdown]
# ### 3.3.4 Dealing With Duplicates <a class="anchor" id="DealingDuplicates"></a>
# Remove duplicate rows. **Note** You may not want to do this - add / remove as required

# %%
df_IQR_dropped = df_IQR_dropped.drop_duplicates(subset='Busbreakdown_ID', keep='first')
df_IQR_dropped.head(3)
# Out:
#    School_Year  Busbreakdown_ID  Run_Type  Bus_No  Route_Number  Reason  \
# 0            0          1227538         7    5689          2570       3
# 1            0          1227539         7    1769          6842       3
# 2            0          1227540         3    7678           470       3
#
#    Occurred_On  Boro  Bus_Company_Name  Number_Of_Students_On_The_Bus  \
# 0       195577     6               102                            NaN
# 1       195577     4                45                            2.0
# 2       195576     1                38                            NaN
#
#    Breakdown_or_Running_Late  Minutes Delayed
# 0                          1                6
# 1                          1                1
# 2                          1                0

# %% [markdown]
# ## 3.4 Split Into test and training DataFrames  <a class="anchor" id="Integratedata"></a>

# %%
import sklearn
from sklearn.model_selection import train_test_split

bus_train_df, bus_test_df = sklearn.model_selection.train_test_split(df_IQR_dropped, test_size=.75, train_size=.25, random_state=2, shuffle = True, stratify = None)

bus_train_df.head(10)
# Out:
#         School_Year  Busbreakdown_ID  Run_Type  Bus_No  Route_Number  Reason  \
# 278812            1          1290076         3   12974           188       3
# 387638            6          1700516         7    9409         10067       6
# 355184            4          1625513         3      96          7996       8
# 71698             1          1318641         0    5540         15031       6
# 403028            6          1687101         7    8289          3909       5
# 337079            3          1557829         7    5791          5647       3
# 10842             0          1244520         7   16238          2793       8
# 465156            6          1709006         7   11376         14843       3
# 106444            2          1437221         7   11489         10423       3
# 147160            0          1247770         3   13011           891       3
#
#         Occurred_On  Boro  Bus_Company_Name  Number_Of_Students_On_The_Bus  \
# ...

# %% [markdown]
# # 4. Stage Four - Exploratory Data Analysis <a class="anchor" id="EDA"></a>

# %%
col = 'Minutes Delayed'
# Histogram & Results
hist_chart(df_IQR_decoded, col)
count_values_table(df_IQR_decoded[col])
# Out:
#        Minutes Delayed  Minutes Delayed
# 16-30           159554             36.0
# 31-45           129023             29.1
# 46-60            63709             14.4
# 0-15             63589             14.4
# 61-90            26442              6.0
# 90+                338              0.1

# %%
col = 'Reason'
# Histogram & Results
hist_chart(df_IQR_decoded, col)

# %%
col = 'Breakdown_or_Running_Late'
# Histogram & Results
count_values_table(df_IQR_decoded[col])
# Out:
#               Breakdown_or_Running_Late  Breakdown_or_Running_Late
# Running Late                     442644                      100.0
# Breakdown                            11                        0.0

# %%
def calc_correlation(data):
    correlation_matrix = data.corr()
    return correlation_matrix

correlation_stats = calc_correlation(df_IQR_dropped)
print(correlation_stats)
# Out:
#                                School_Year  Busbreakdown_ID  Run_Type  \
# School_Year                       1.000000         0.980146  0.033103
# Busbreakdown_ID                   0.980146         1.000000  0.036409
# Run_Type                          0.033103         0.036409  1.000000
# Bus_No                           -0.054379        -0.071736 -0.047641
# Route_Number                      0.069462         0.064281  0.105159
# Reason                           -0.020133        -0.024588 -0.020213
# Occurred_On                       0.175656         0.103782  0.019365
# Boro                              0.004995        -0.008743  0.067814
# Bus_Company_Name                 -0.005077        -0.007200 -0.008605
# Number_Of_Students_On_The_Bus    -0.025776        -0.036245 -0.003577
# Breakdown_or_Running_Late         0.082556         0.079410  0.013329
# Minutes Delayed                   0.096858         0.104286  0.069885
#
# ...

# %% [markdown]
# # 5. Stage Four - Modelling <a class="anchor" id="Modelling"></a>
# As the first step in modelling, you'll select the actual modelling technique that you'll be using. Although you may have already selected a tool during the business understanding phase, at this stage you'll be selecting the specific modelling technique e.g. decision-tree building with C5.0, or neural network generation with back propagation. If multiple techniques are applied, perform this task separately for each technique.

# %% [markdown]
# ## 5.1. Modelling technique <a class="anchor" id="ModellingTechnique"></a>
# Document the actual modelling technique that is to be used.
#
# Import Models below:

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score

# %% [markdown]
# ## 5.2. Modelling assumptions <a class="anchor" id="ModellingAssumptions"></a>
# Many modelling techniques make specific assumptions about the data, for example that all attributes have uniform distributions, no missing values allowed, class attribute must be symbolic etc. Record any assumptions made.
#
# - Naive Bayes assumes that every feature makes an equal contribution to the target variable, in this case the classification as a breakdown or running late.

# %% [markdown]
# ## 5.3. Build Model <a class="anchor" id="BuildModel"></a>
# Run the modelling tool on the prepared dataset to create one or more models.

# %%
df_IQR_dropped = df_IQR_dropped.dropna() 
print(df_IQR_dropped.columns)
# Out:
# Index(['School_Year', 'Busbreakdown_ID', 'Run_Type', 'Bus_No', 'Route_Number',
#        'Reason', 'Occurred_On', 'Boro', 'Bus_Company_Name',
#        'Number_Of_Students_On_The_Bus', 'Breakdown_or_Running_Late',
#        'Minutes Delayed'],
#       dtype='object')

# %%
def NB_classifier_target(data, col):
    #Separate features
    x = data.drop(col, axis =1)
    y = data[col]
    #Split into test and training sets for features
    x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25, random_state=2)  
    naive_bayes = GaussianNB()
    naive_bayes.fit(x_train, y_train)
    y_pred=naive_bayes.predict(x_test)
    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred, average='weighted',zero_division=1.0)
    return accuracy, precision

# %%
B_or_RL_accuracy, B_or_RL_precision = NB_classifier_target(df_IQR_dropped, 'Breakdown_or_Running_Late')
print("Accuracy:", B_or_RL_accuracy)
print("Precision:", B_or_RL_precision)
# Out:
# Accuracy: 0.9057876259084029
# Precision: 0.9146635973403779

# %%
Minutes_Delayed_accuracy, Minutes_Delayed_precision = NB_classifier_target(df_IQR_dropped, 'Minutes Delayed')
print("Accuracy:", Minutes_Delayed_accuracy)
print("Precision:", Minutes_Delayed_precision)
# Out:
# Accuracy: 0.41807533502928285
# Precision: 0.40526214497499796

# %%
Reason_accuracy, Reason_precision = NB_classifier_target(df_IQR_dropped, 'Reason')
print("Accuracy:", Reason_accuracy)
print("Precision:", Reason_precision)
# Out:
# Accuracy: 0.6233407035813066
# Precision: 0.6195152071624631

# %% [markdown]
# ## 5.4. Assess Model <a class="anchor" id="AssessModel"></a>
# Interpret the models according to your domain knowledge, your data mining success criteria and your desired test design. Judge the success of the application of modelling and discovery techniques technically, then contact business analysts and domain experts later in order to discuss the data mining results in the business context. This task only considers models, whereas the evaluation phase also takes into account all other results that were produced in the course of the project.
#
# At this stage you should rank the models and assess them according to the evaluation criteria. You should take the business objectives and business success criteria into account as far as you can here. In most data mining projects a single technique is applied more than once and data mining results are generated with several different techniques.
#
# **Model assessment** - Summarise the results of this task, list the qualities of your generated models (e.g.in terms of accuracy) and rank their quality in relation to each other.
# - The model predicts whether the issue is a breakdown or delay with high accuracy and precision. I do not think this is necessarily the most helpful prediciton, because at this point there's already been a breakdown or delay that's impact the bus.
# - More interesting from the model is that it has high accuracy and preicision in determining the length of minutes that might impact the route. While this isn't necessarily what I initially set out to find, this can be useful when having a breakdown or delay reported because it can indicate the length of time that the transportation department can expect the impact the route. This means they could effectively communmicate with schools, or even plan for the route to leave earlier depneding on the nature of the input they have available prior to the bus leaving the schools/station.
# - I tried running the model for the columns Bus_No and Reason, but the model was very inaccurate at predicting either of these. I was curious about these two features because bus number could have repeat issues that might show up in the model, and reasons might be able to be ascertained using other columns like minutes delayed or breakdown or running late.
#
# I then decided to see if a logistic regression would provide any additional insight.

# %%
#OneHot Encoding Fucntion
def onehot_encoding(data):
    encoded_data = pd.get_dummies(data, sparse=True)
    return encoded_data
    
df_IQR_onehot = onehot_encoding(df_IQR_dropped)

# %%
df_IQR_onehot.sample(5)
# Out:
#         School_Year  Busbreakdown_ID  Run_Type  Bus_No  Route_Number  Reason  \
# 452935            5          1654994         7    2635          8450       3
# 65197             1          1310754         7    3139          2598       3
# 272226            3          1501029         0    2862          4257       3
# 26507             0          1264948         7    2890          6293       3
# 457406            6          1663871         7    3086          6943       3
#
#         Occurred_On  Boro  Bus_Company_Name  Number_Of_Students_On_The_Bus  \
# 452935       109471     4                58                            1.0
# 65197        241102     4                12                            0.0
# 272226       240379     2                10                            1.0
# 26507         87614     4                85                            3.0
# 457406       149945     4                45                            0.0
#
#         Breakdown_or_Running_Late  Minutes Delayed
# ...

# %%
#Create regression model - Logsitic Regression? https://www.upgrad.com/blog/types-of-regression-models-in-machine-learning/
#https://realpython.com/logistic-regression-python/
from sklearn.linear_model import LogisticRegression

def log_regression_model(data, col):
    x=data.drop(col, axis=1)
    y = data[col]
    x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25, random_state=2)  
    logreg = LogisticRegression()
    logreg.fit(x_train, y_train)
    train_accuracy = logreg.score(x_train, y_train)
    test_accuracy = logreg.score(x_test, y_test)
    print("Training accuracy:", train_accuracy)
    print("Testing accuracy:", test_accuracy)
    return logreg

logreg = log_regression_model(df_IQR_onehot, 'Breakdown_or_Running_Late')
# Out:
# Training accuracy: 0.9055781860064562
# Testing accuracy: 0.9057876259084029

# %%
import warnings
from sklearn.exceptions import ConvergenceWarning
warnings.filterwarnings("ignore", category=ConvergenceWarning) #This warning would be prompted, and changing max iteratiosn to over 1000 still displayed the message. A standard scaler made the accuracy worse.
logreg = log_regression_model(df_IQR_onehot, 'Reason')
# Out:
# Training accuracy: 0.6224078447533457
# Testing accuracy: 0.6233644785747684

# %%
logreg = log_regression_model(df_IQR_onehot, 'Minutes Delayed')
# Out:
# Training accuracy: 0.3415542628901111
# Testing accuracy: 0.34580727990299803

# %%
logreg = log_regression_model(df_IQR_onehot, 'Run_Type')
# Out:
# Training accuracy: 0.6540658202701918
# Testing accuracy: 0.6534794702931457

# %% [markdown]
# # 6. Stage 5 - Evaluation and Stage 6 - Deployment
# This information will be contained in a written report and presentation of findings. Please see attached documents for this component.

# %%
df_IQR_decoded.to_csv(r'C:\Users\jenni\OneDrive\Documents\BusDataFrame.csv', index=True)
